# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
from  matplotlib.ticker import PercentFormatter
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import ks_2samp
from scipy.stats import ttest_ind
from scipy.stats import kruskal
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

import os
import json

with open('data/paths.json','r') as f:
    paths = json.load(f)

data_path = paths["data_path"]

# %% [markdown]
# <h1 style="color: red">Analysis of Brain Tissue Metabolytes Data</h1>

# %% [markdown]
# <p> The study is based on the following process:: we integrate the chromatographic peak for each lipid species to obtain the “area”. The peak area of the lipid species is then normalized to the internal standard (“IS Area”) to obtain the “area ratio”.  The area ratios are then normalized to the tissue weight of the original sample.</p>
# <p>
# The weight normalized area ratio of each lipid species in each sample was then used to create the pivot tables and perform statistical analysis. </p>

# %% [markdown]
# <h2>Preprocessing data</h2>

# %%
# importing file inside pandas dataframe

df = pd.read_excel(os.path.join(data_path,"2022_12_Laezza_Bernabucci_Mouse_Brain_COMBINED_METABOLOMICS.xlsx"))

# %%
df.head(20)
# Out:
#     Sample Number Sample Submission Date Sample Name Sex  Tissue weight\n(mg)  \
# 0               1                09/2021      C20M1S   M                   56
# 1               1                09/2021      C20M1S   M                   56
# 2               1                09/2021      C20M1S   M                   56
# 3               1                09/2021      C20M1S   M                   56
# 4               1                09/2021      C20M1S   M                   56
# 5               1                09/2021      C20M1S   M                   56
# 6               1                09/2021      C20M1S   M                   56
# 7               1                09/2021      C20M1S   M                   56
# 8               1                09/2021      C20M1S   M                   56
# 9               1                09/2021      C20M1S   M                   56
# 10              1                09/2021      C20M1S   M                   56
# 11              1                09/2021      C20M1S   M                   56
# 12              1                09/2021      C20M1S   M                   56
# 13              1                09/2021      C20M1S   M                   56
# 14              1                09/2021      C20M1S   M                   56
# 15              1                09/2021      C20M1S   M                   56
# 16              1                09/2021      C20M1S   M                   56
# 17              1                09/2021      C20M1S   M                   56
# 18              1                09/2021      C20M1S   M                   56
# 19              1                09/2021      C20M1S   M                   56
#
#    Treatment Tissue Type  PND Litter                      Metabolite  \
# 0    control    striatum   30    C20                          Urea.1
# 1    control    striatum   30    C20                  Ethanolamine.1
# 2    control    striatum   30    C20                     Imidazole.1
# 3    control    striatum   30    C20        Trimethylamine-N-oxide.1
# 4    control    striatum   30    C20                       Glycine.2
# 5    control    striatum   30    C20                     Sarcosine.1
# 6    control    striatum   30    C20                     L-Alanine.1
# 7    control    striatum   30    C20                     B-Alanine.1
# 8    control    striatum   30    C20              Betaine Lldehyde.1
# 9    control    striatum   30    C20               Dimethylglycine.1
# 10   control    striatum   30    C20        Aminobutyric acid(Abu).1
# 11   control    striatum   30    C20  Aminoisobutyric acid (BAIBA).1
# 12   control    striatum   30    C20                          GABA.2
# 13   control    striatum   30    C20                       Choline.1
# 14   control    striatum   30    C20                        Serine.1
# 15   control    striatum   30    C20                        Uracil.1
# 16   control    striatum   30    C20                    Creatinine.1
# 17   control    striatum   30    C20                       Proline.1
# 18   control    striatum   30    C20                      L-Valine.1
# 19   control    striatum   30    C20           5-Aminovaleric Acid.1
#
#    MRM Transition of each lipid species\n(Parent ion/Fragment ion)  \
# 0                                         61.0 / 44.0
# 1                                         62.1 / 44.1
# 2                                         69.0 / 42.2
# 3                                         76.0 / 58.1
# 4                                         76.0 / 30.0
# 5                                         90.0 / 44.0
# 6                                         90.1 / 44.1
# 7                                         90.1 / 30.1
# 8                                        102.0 / 58.0
# 9                                        104.1 / 58.1
# 10                                       104.1 / 58.0
# 11                                       104.1 / 86.0
# 12                                       104.2 / 87.1
# 13                                       105.1 / 60.1
# 14                                       106.0 / 60.0
# 15                                       113.0 / 70.0
# 16                                       114.0 / 44.0
# 17                                       116.1 / 70.0
# 18                                       118.0 / 55.1
# 19                                      118.0 / 101.0
#
#    Metabolite used as Internal Standard  Retention Time\n(min)  \
# 0                     L-Tryptophan.1.IS               1.959026
# 1                     L-Tryptophan.1.IS               9.962347
# 2                     L-Tryptophan.1.IS               2.478150
# 3                     L-Tryptophan.1.IS               4.874291
# 4                     L-Tryptophan.1.IS               6.283526
# 5                     L-Tryptophan.1.IS               4.496771
# 6                     L-Tryptophan.1.IS               5.105011
# 7                     L-Tryptophan.1.IS               6.472060
# 8                     L-Tryptophan.1.IS               0.000000
# 9                     L-Tryptophan.1.IS               0.000000
# 10                    L-Tryptophan.1.IS               4.054535
# 11                    L-Tryptophan.1.IS               4.675121
# 12                    L-Tryptophan.1.IS               7.015215
# 13                    L-Tryptophan.1.IS               0.000000
# 14                    L-Tryptophan.1.IS               6.771218
# 15                    L-Tryptophan.1.IS               8.244754
# 16                    L-Tryptophan.1.IS               1.817171
# 17                    L-Tryptophan.1.IS               3.557168
# 18                    L-Tryptophan.1.IS               3.199044
# 19                    L-Tryptophan.1.IS               6.095700
#
#     Peak Area of Metabolite  Peak Area of Internal Standard  \
# 0              5.326877e+07                    1.792767e+07
# 1              1.287801e+07                    1.792767e+07
# 2              1.576080e+05                    1.792767e+07
# 3              1.159692e+07                    1.792767e+07
# 4              4.631088e+06                    1.792767e+07
# 5              6.496060e+04                    1.792767e+07
# 6              2.110331e+07                    1.792767e+07
# 7              1.848149e+06                    1.792767e+07
# 8              0.000000e+00                    1.792767e+07
# 9              0.000000e+00                    1.792767e+07
# 10             3.033726e+06                    1.792767e+07
# 11             6.632156e+05                    1.792767e+07
# 12             2.923420e+08                    1.792767e+07
# 13             0.000000e+00                    1.792767e+07
# 14             4.970589e+07                    1.792767e+07
# 15             1.396068e+05                    1.792767e+07
# 16             2.335771e+07                    1.792767e+07
# 17             1.587958e+08                    1.792767e+07
# 18             1.866088e+07                    1.792767e+07
# 19             2.652301e+06                    1.792767e+07
#
#     Normalized Peak Area\n(Peak Area of Metabolite / (Peak Area of Internal Standard * Tisue weight))
# 0                                            0.053059
# 1                                            0.012827
# 2                                            0.000157
# 3                                            0.011551
# 4                                            0.004613
# 5                                            0.000065
# 6                                            0.021020
# 7                                            0.001841
# 8                                            0.000000
# 9                                            0.000000
# 10                                           0.003022
# 11                                           0.000661
# 12                                           0.291192
# 13                                           0.000000
# 14                                           0.049510
# 15                                           0.000139
# 16                                           0.023266
# 17                                           0.158171
# 18                                           0.018587
# 19                                           0.002642

# %%
# number of rows and columns

df.shape
# Out:
# (16200, 16)

# %%
# titles of the columns

print(df.columns.values)
# Out:
# ['Sample Number' 'Sample Submission Date' 'Sample Name' 'Sex'
#  'Tissue weight\n(mg)' 'Treatment' 'Tissue Type' 'PND' 'Litter'
#  'Metabolite'
#  'MRM Transition of each lipid species\n(Parent ion/Fragment ion)'
#  'Metabolite used as Internal Standard' 'Retention Time\n(min)'
#  'Peak Area of Metabolite' 'Peak Area of Internal Standard'
#  'Normalized Peak Area\n(Peak Area of Metabolite / (Peak Area of Internal Standard * Tisue weight))']

# %%
# unique subjects

len(df['Sample Name'].unique())
# Out:
# 72

# %%
# Assign normalization factor

""" le = LabelEncoder()
le.fit(df[['IS Name', 'Component Name']].values.flatten().ravel())
df['normFactor'] = le.transform(df['IS Name'])
df['normFactor'] = df.apply(lambda x: 
        x['normFactor'] if not x['is Normalization Factor'] else
        le.transform(np.asarray([x['Component Name']]))[0], axis=1)
df['normFactor'] = le.fit_transform(df['normFactor']) """

# %%
# Let's check if there are NaN values in the 3 new columns. If there are NaN values the relabelling process is incorrect

print(df['Sex'].isnull().values.any())
print(df['Treatment'].isnull().values.any())
print(df['Tissue Type'].isnull().values.any())
print(df['PND'].isnull().values.any())
# Out:
# False
# False
# False
# False

# %%
# There are other columns which present NaN values; 
# The column that we called 'Normalized Area' has some N/A values... 

print(df['Normalized Peak Area\n(Peak Area of Metabolite / (Peak Area of Internal Standard * Tisue weight))'].isnull().values.sum())
# Out:
# 0

# %%
# Number of group components

len(df['Metabolite'].unique())
# Out:
# 225

# %%
# Let's consider only rows where Normalized Area greater than 0.00001

df_clean = df[df['Normalized Peak Area\n(Peak Area of Metabolite / (Peak Area of Internal Standard * Tisue weight))'] > 0.00001]
print(df_clean['Normalized Peak Area\n(Peak Area of Metabolite / (Peak Area of Internal Standard * Tisue weight))'].isnull().values.sum())
# Out:
# 0

# %%
# Numbers of unique components in the dataframe without null values

len(df_clean['Sample Number'].unique())
# Out:
# 72

# %%
df_clean.head(30)
# Out:
#     Sample Number Sample Submission Date Sample Name Sex  Tissue weight\n(mg)  \
# 0               1                09/2021      C20M1S   M                   56
# 1               1                09/2021      C20M1S   M                   56
# 2               1                09/2021      C20M1S   M                   56
# 3               1                09/2021      C20M1S   M                   56
# 4               1                09/2021      C20M1S   M                   56
# 5               1                09/2021      C20M1S   M                   56
# 6               1                09/2021      C20M1S   M                   56
# 7               1                09/2021      C20M1S   M                   56
# 10              1                09/2021      C20M1S   M                   56
# 11              1                09/2021      C20M1S   M                   56
# 12              1                09/2021      C20M1S   M                   56
# 14              1                09/2021      C20M1S   M                   56
# 15              1                09/2021      C20M1S   M                   56
# 16              1                09/2021      C20M1S   M                   56
# 17              1                09/2021      C20M1S   M                   56
# 18              1                09/2021      C20M1S   M                   56
# 19              1                09/2021      C20M1S   M                   56
# 20              1                09/2021      C20M1S   M                   56
# 21              1                09/2021      C20M1S   M                   56
# 22              1                09/2021      C20M1S   M                   56
# 23              1                09/2021      C20M1S   M                   56
# 24              1                09/2021      C20M1S   M                   56
# 25              1                09/2021      C20M1S   M                   56
# 26              1                09/2021      C20M1S   M                   56
# 28              1                09/2021      C20M1S   M                   56
# 29              1                09/2021      C20M1S   M                   56
# 30              1                09/2021      C20M1S   M                   56
# 31              1                09/2021      C20M1S   M                   56
# 32              1                09/2021      C20M1S   M                   56
# 33              1                09/2021      C20M1S   M                   56
#
#    Treatment Tissue Type  PND Litter                      Metabolite  \
# 0    control    striatum   30    C20                          Urea.1
# 1    control    striatum   30    C20                  Ethanolamine.1
# 2    control    striatum   30    C20                     Imidazole.1
# 3    control    striatum   30    C20        Trimethylamine-N-oxide.1
# 4    control    striatum   30    C20                       Glycine.2
# 5    control    striatum   30    C20                     Sarcosine.1
# 6    control    striatum   30    C20                     L-Alanine.1
# 7    control    striatum   30    C20                     B-Alanine.1
# 10   control    striatum   30    C20        Aminobutyric acid(Abu).1
# 11   control    striatum   30    C20  Aminoisobutyric acid (BAIBA).1
# 12   control    striatum   30    C20                          GABA.2
# 14   control    striatum   30    C20                        Serine.1
# 15   control    striatum   30    C20                        Uracil.1
# 16   control    striatum   30    C20                    Creatinine.1
# 17   control    striatum   30    C20                       Proline.1
# 18   control    striatum   30    C20                      L-Valine.1
# 19   control    striatum   30    C20           5-Aminovaleric Acid.1
# 20   control    striatum   30    C20                       Betaine.1
# 21   control    striatum   30    C20                  L-Homoserine.1
# 22   control    striatum   30    C20                     Threonine.1
# 23   control    striatum   30    C20                        Purine.1
# 24   control    striatum   30    C20                  Nicotinamide.1
# 25   control    striatum   30    C20                       Thymine.1
# 26   control    striatum   30    C20                    Pipecolate.1
# 28   control    striatum   30    C20                  Hydroxyproline
# 29   control    striatum   30    C20                       Leucine.2
# 30   control    striatum   30    C20                    Isoleucine.2
# 31   control    striatum   30    C20                  L-Asparagine.1
# 32   control    striatum   30    C20                     Ornithine.1
# 33   control    striatum   30    C20                       Adenine.1
#
#    MRM Transition of each lipid species\n(Parent ion/Fragment ion)  \
# 0                                         61.0 / 44.0
# 1                                         62.1 / 44.1
# 2                                         69.0 / 42.2
# 3                                         76.0 / 58.1
# 4                                         76.0 / 30.0
# 5                                         90.0 / 44.0
# 6                                         90.1 / 44.1
# 7                                         90.1 / 30.1
# 10                                       104.1 / 58.0
# 11                                       104.1 / 86.0
# 12                                       104.2 / 87.1
# 14                                       106.0 / 60.0
# 15                                       113.0 / 70.0
# 16                                       114.0 / 44.0
# 17                                       116.1 / 70.0
# 18                                       118.0 / 55.1
# 19                                      118.0 / 101.0
# 20                                       119.1 / 59.0
# 21                                       120.0 / 74.0
# 22                                       120.1 / 74.0
# 23                                       121.1 / 93.9
# 24                                       123.1 / 80.0
# 25                                      127.1 / 110.0
# 26                                       130.0 / 84.0
# 28                                       132.0 / 68.2
# 29                                       132.1 / 43.1
# 30                                       132.1 / 69.0
# 31                                       133.1 / 87.1
# 32                                       133.1 / 70.0
# 33                                      136.0 / 119.0
#
#    Metabolite used as Internal Standard  Retention Time\n(min)  \
# 0                     L-Tryptophan.1.IS               1.959026
# 1                     L-Tryptophan.1.IS               9.962347
# 2                     L-Tryptophan.1.IS               2.478150
# 3                     L-Tryptophan.1.IS               4.874291
# 4                     L-Tryptophan.1.IS               6.283526
# 5                     L-Tryptophan.1.IS               4.496771
# 6                     L-Tryptophan.1.IS               5.105011
# 7                     L-Tryptophan.1.IS               6.472060
# 10                    L-Tryptophan.1.IS               4.054535
# 11                    L-Tryptophan.1.IS               4.675121
# 12                    L-Tryptophan.1.IS               7.015215
# 14                    L-Tryptophan.1.IS               6.771218
# 15                    L-Tryptophan.1.IS               8.244754
# 16                    L-Tryptophan.1.IS               1.817171
# 17                    L-Tryptophan.1.IS               3.557168
# 18                    L-Tryptophan.1.IS               3.199044
# 19                    L-Tryptophan.1.IS               6.095700
# 20                    L-Tryptophan.1.IS               2.930385
# 21                    L-Tryptophan.1.IS               8.602953
# 22                    L-Tryptophan.1.IS               5.129281
# 23                    L-Tryptophan.1.IS               2.106738
# 24                    L-Tryptophan.1.IS               6.904605
# 25                    L-Tryptophan.1.IS               1.201429
# 26                    L-Tryptophan.1.IS               6.320573
# 28                    L-Tryptophan.1.IS               4.887345
# 29                    L-Tryptophan.1.IS               2.245674
# 30                    L-Tryptophan.1.IS               2.465851
# 31                    L-Tryptophan.1.IS               6.596523
# 32                    L-Tryptophan.1.IS              14.395899
# 33                    L-Tryptophan.1.IS               1.529047
#
#     Peak Area of Metabolite  Peak Area of Internal Standard  \
# 0              5.326877e+07                    1.792767e+07
# 1              1.287801e+07                    1.792767e+07
# 2              1.576080e+05                    1.792767e+07
# 3              1.159692e+07                    1.792767e+07
# 4              4.631088e+06                    1.792767e+07
# 5              6.496060e+04                    1.792767e+07
# 6              2.110331e+07                    1.792767e+07
# 7              1.848149e+06                    1.792767e+07
# 10             3.033726e+06                    1.792767e+07
# 11             6.632156e+05                    1.792767e+07
# 12             2.923420e+08                    1.792767e+07
# 14             4.970589e+07                    1.792767e+07
# 15             1.396068e+05                    1.792767e+07
# 16             2.335771e+07                    1.792767e+07
# 17             1.587958e+08                    1.792767e+07
# 18             1.866088e+07                    1.792767e+07
# 19             2.652301e+06                    1.792767e+07
# 20             1.169053e+07                    1.792767e+07
# 21             1.854674e+05                    1.792767e+07
# 22             1.802586e+07                    1.792767e+07
# 23             5.288704e+05                    1.792767e+07
# 24             1.630907e+05                    1.792767e+07
# 25             2.263055e+06                    1.792767e+07
# 26             8.732032e+08                    1.792767e+07
# 28             4.699214e+06                    1.792767e+07
# 29             1.387525e+07                    1.792767e+07
# 30             8.745269e+06                    1.792767e+07
# 31             1.105943e+07                    1.792767e+07
# 32             9.341348e+05                    1.792767e+07
# 33             7.766679e+07                    1.792767e+07
#
#     Normalized Peak Area\n(Peak Area of Metabolite / (Peak Area of Internal Standard * Tisue weight))
# 0                                            0.053059
# 1                                            0.012827
# 2                                            0.000157
# 3                                            0.011551
# 4                                            0.004613
# 5                                            0.000065
# 6                                            0.021020
# 7                                            0.001841
# 10                                           0.003022
# 11                                           0.000661
# 12                                           0.291192
# 14                                           0.049510
# 15                                           0.000139
# 16                                           0.023266
# 17                                           0.158171
# 18                                           0.018587
# 19                                           0.002642
# 20                                           0.011645
# 21                                           0.000185
# 22                                           0.017955
# 23                                           0.000527
# 24                                           0.000162
# 25                                           0.002254
# 26                                           0.869768
# 28                                           0.004681
# 29                                           0.013821
# 30                                           0.008711
# 31                                           0.011016
# 32                                           0.000930
# 33                                           0.077361

# %%
# Change column names to camelCase
""" cn = df.columns
cn_camelCase = [x.title().replace('/','').replace(' ','').replace('(','').replace(')','') for x in cn]
cn_camelCase = [''.join([x[0].lower(), x[1:]]) for x in cn_camelCase]
cn_camelCase """
# Out:
# ['sampleNumber',
#  'sampleSubmissionDate',
#  'sampleName',
#  'sex',
#  'tissueWeightMg',
#  'treatment',
#  'tissueType',
#  'pnd',
#  'litter',
#  'individualLipidSpecies',
#  'lipidClass',
#  'mrmTransitionOfEachLipidSpecies\nParentIonFragmentIon',
#  'lipidSpeciesUsedAsInternalStandard',
#  'retentionTimeMin',
#  'peakAreaOfLipidSpecies',
#  'peakAreaOfInternalStandard',
#  'normalizedPeakAreaPeakAreaOfLipidSpeciesPeakAreaOfInternalStandard*TissueWeight']

# %%
# Save dataframe to data_path

df_clean.to_csv(os.path.join(data_path, 'clean_data_metabolites.csv'), index=False)
