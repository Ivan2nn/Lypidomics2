# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
from  matplotlib.ticker import PercentFormatter
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import ks_2samp
from scipy.stats import ttest_ind
from scipy.stats import kruskal
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder

import os
import json

with open('data/paths.json','r') as f:
    paths = json.load(f)

data_path = paths["data_path"]

# %% [markdown]
# <h1 style="color: red">Analysis of Brain Tissue Lipids Data</h1>

# %% [markdown]
# <p> The study is based on the following process:: we integrate the chromatographic peak for each lipid species to obtain the “area”. The peak area of the lipid species is then normalized to the internal standard (“IS Area”) to obtain the “area ratio”.  The area ratios are then normalized to the tissue weight of the original sample.</p>
# <p>
# The weight normalized area ratio of each lipid species in each sample was then used to create the pivot tables and perform statistical analysis. </p>

# %% [markdown]
# <h2>Preprocessing data</h2>

# %%
# importing file inside pandas dataframe

df = pd.read_excel(os.path.join(data_path,"2022_12_Laezza_Mouse_Brain_deltamethrin_COMBINED_LIPIDOMICS_bc.xlsx"))

# %%
df.head()
# Out:
#    Sample Number Sample Submission Date Sample Name Sex  Tissue weight (mg)  \
# 0              1                09/2021      C20M1S   M                  56
# 1              1                09/2021      C20M1S   M                  56
# 2              1                09/2021      C20M1S   M                  56
# 3              1                09/2021      C20M1S   M                  56
# 4              1                09/2021      C20M1S   M                  56
#
#   Treatment Tissue Type  PND Litter Individual Lipid Species Lipid Class  \
# 0   control    striatum   30    C20               SM(14:0)+H          SM
# 1   control    striatum   30    C20               SM(16:0)+H          SM
# 2   control    striatum   30    C20               SM(18:0)+H          SM
# 3   control    striatum   30    C20               SM(18:1)+H          SM
# 4   control    striatum   30    C20               SM(20:0)+H          SM
#
#   MRM Transition of each lipid species\n(Parent ion / Fragment ion)  \
# 0                                      675.5 / 184.1
# 1                                      703.6 / 184.1
# 2                                      731.6 / 184.1
# 3                                      729.6 / 184.1
# 4                                      759.6 / 184.1
#
#   Lipid Species used as Internal Standard  Retention Time (min)  \
# 0                 SM(18:1)+H_d9_SPLASH.IS             12.737513
# 1                 SM(18:1)+H_d9_SPLASH.IS             12.662914
# 2                 SM(18:1)+H_d9_SPLASH.IS             12.580159
# 3                 SM(18:1)+H_d9_SPLASH.IS             12.572303
# 4                 SM(18:1)+H_d9_SPLASH.IS             12.486523
#
#    Peak Area of Lipid Species  Peak Area of Internal Standard  \
# 0                4.116176e+06                    4.165659e+07
# 1                2.433723e+07                    4.165659e+07
# 2                1.432478e+08                    4.165659e+07
# 3                1.268323e+08                    4.165659e+07
# 4                5.419340e+06                    4.165659e+07
#
#    Normalized Peak Area (Peak Area of Lipid Species / (Peak Area of Internal Standard * Tissue Weight))
# 0                                           0.000842
# 1                                           0.006390
# 2                                           0.036989
# 3                                           0.046320
# 4                                           0.001167

# %%
# number of rows and columns

df.shape
# Out:
# (82152, 17)

# %%
# titles of the columns

print(df.columns.values)
# Out:
# ['Sample Number' 'Sample Submission Date' 'Sample Name' 'Sex'
#  'Tissue weight (mg)' 'Treatment' 'Tissue Type' 'PND' 'Litter'
#  'Individual Lipid Species' 'Lipid Class'
#  'MRM Transition of each lipid species\n(Parent ion / Fragment ion)'
#  'Lipid Species used as Internal Standard' 'Retention Time (min)'
#  'Peak Area of Lipid Species' 'Peak Area of Internal Standard'
#  'Normalized Peak Area (Peak Area of Lipid Species / (Peak Area of Internal Standard * Tissue Weight))']

# %%
# unique subjects

len(df['Sample Name'].unique())
# Out:
# 72

# %%
# Assign normalization factor

""" le = LabelEncoder()
le.fit(df[['IS Name', 'Component Name']].values.flatten().ravel())
df['normFactor'] = le.transform(df['IS Name'])
df['normFactor'] = df.apply(lambda x: 
        x['normFactor'] if not x['is Normalization Factor'] else
        le.transform(np.asarray([x['Component Name']]))[0], axis=1)
df['normFactor'] = le.fit_transform(df['normFactor']) """

# %%
# Let's check if there are NaN values in the 3 new columns. If there are NaN values the relabelling process is incorrect

print(df['Sex'].isnull().values.any())
print(df['Treatment'].isnull().values.any())
print(df['Tissue Type'].isnull().values.any())
print(df['PND'].isnull().values.any())
# Out:
# False
# False
# False
# False

# %%
# There are other columns which present NaN values; 
# The column that we called 'Normalized Area' has some N/A values... 

print(df['Normalized Peak Area (Peak Area of Lipid Species / (Peak Area of Internal Standard * Tissue Weight))'].isnull().values.sum())
# Out:
# 38718

# %%
# Number of group components

len(df['Lipid Class'].unique())
# Out:
# 21

# %%
# Let's consider only rows where Normalized Area is not null

df_clean = df.dropna(subset=['Normalized Peak Area (Peak Area of Lipid Species / (Peak Area of Internal Standard * Tissue Weight))'])
print(df_clean['Normalized Peak Area (Peak Area of Lipid Species / (Peak Area of Internal Standard * Tissue Weight))'].isnull().values.sum())
# Out:
# 0

# %%
# Numbers of unique components in the dataframe without null values

len(df_clean['Sample Number'].unique())
# Out:
# 72

# %%
list_of_lipid_classes = df_clean['Lipid Class'].unique().tolist()

# %%
df_clean.head(30)
# Out:
#     Sample Number Sample Submission Date Sample Name Sex  Tissue weight (mg)  \
# 0               1                09/2021      C20M1S   M                  56
# 1               1                09/2021      C20M1S   M                  56
# 2               1                09/2021      C20M1S   M                  56
# 3               1                09/2021      C20M1S   M                  56
# 4               1                09/2021      C20M1S   M                  56
# 5               1                09/2021      C20M1S   M                  56
# 7               1                09/2021      C20M1S   M                  56
# 8               1                09/2021      C20M1S   M                  56
# 9               1                09/2021      C20M1S   M                  56
# 10              1                09/2021      C20M1S   M                  56
# 13              1                09/2021      C20M1S   M                  56
# 17              1                09/2021      C20M1S   M                  56
# 19              1                09/2021      C20M1S   M                  56
# 20              1                09/2021      C20M1S   M                  56
# 21              1                09/2021      C20M1S   M                  56
# 25              1                09/2021      C20M1S   M                  56
# 26              1                09/2021      C20M1S   M                  56
# 27              1                09/2021      C20M1S   M                  56
# 30              1                09/2021      C20M1S   M                  56
# 32              1                09/2021      C20M1S   M                  56
# 33              1                09/2021      C20M1S   M                  56
# 34              1                09/2021      C20M1S   M                  56
# 35              1                09/2021      C20M1S   M                  56
# 36              1                09/2021      C20M1S   M                  56
# 37              1                09/2021      C20M1S   M                  56
# 38              1                09/2021      C20M1S   M                  56
# 39              1                09/2021      C20M1S   M                  56
# 40              1                09/2021      C20M1S   M                  56
# 41              1                09/2021      C20M1S   M                  56
# 42              1                09/2021      C20M1S   M                  56
#
#    Treatment Tissue Type  PND Litter Individual Lipid Species Lipid Class  \
# 0    control    striatum   30    C20               SM(14:0)+H          SM
# 1    control    striatum   30    C20               SM(16:0)+H          SM
# 2    control    striatum   30    C20               SM(18:0)+H          SM
# 3    control    striatum   30    C20               SM(18:1)+H          SM
# 4    control    striatum   30    C20               SM(20:0)+H          SM
# 5    control    striatum   30    C20               SM(20:1)+H          SM
# 7    control    striatum   30    C20               SM(22:1)+H          SM
# 8    control    striatum   30    C20               SM(24:0)+H          SM
# 9    control    striatum   30    C20               SM(24:1)+H          SM
# 10   control    striatum   30    C20               SM(26:0)+H          SM
# 13   control    striatum   30    C20               CE(22:6)+H          CE
# 17   control    striatum   30    C20               CE(14:0)+H          CE
# 19   control    striatum   30    C20               CE(16:1)+H          CE
# 20   control    striatum   30    C20               CE(18:0)+H          CE
# 21   control    striatum   30    C20               CE(18:1)+H          CE
# 25   control    striatum   30    C20               CE(20:3)+H          CE
# 26   control    striatum   30    C20               CE(20:4)+H          CE
# 27   control    striatum   30    C20               CE(20:5)+H          CE
# 30   control    striatum   30    C20               CE(22:2)+H          CE
# 32   control    striatum   30    C20               CE(24:1)+H          CE
# 33   control    striatum   30    C20              CER(14:0)+H         CER
# 34   control    striatum   30    C20              CER(16:0)+H         CER
# 35   control    striatum   30    C20              CER(18:0)+H         CER
# 36   control    striatum   30    C20              CER(18:1)+H         CER
# 37   control    striatum   30    C20              CER(20:0)+H         CER
# 38   control    striatum   30    C20              CER(20:1)+H         CER
# 39   control    striatum   30    C20              CER(22:0)+H         CER
# 40   control    striatum   30    C20              CER(22:1)+H         CER
# 41   control    striatum   30    C20              CER(24:0)+H         CER
# 42   control    striatum   30    C20              CER(24:1)+H         CER
#
#    MRM Transition of each lipid species\n(Parent ion / Fragment ion)  \
# 0                                       675.5 / 184.1
# 1                                       703.6 / 184.1
# 2                                       731.6 / 184.1
# 3                                       729.6 / 184.1
# 4                                       759.6 / 184.1
# 5                                       757.6 / 184.1
# 7                                       785.7 / 184.1
# 8                                       815.7 / 184.1
# 9                                       813.7 / 184.1
# 10                                      843.7 / 184.1
# 13                                      714.6 / 369.4
# 17                                      614.6 / 369.4
# 19                                      640.6 / 369.4
# 20                                      670.6 / 369.4
# 21                                      668.6 / 369.4
# 25                                      692.6 / 369.4
# 26                                      690.6 / 369.4
# 27                                      688.6 / 369.4
# 30                                      722.7 / 369.4
# 32                                      752.7 / 369.4
# 33                                      510.6 / 264.4
# 34                                      538.6 / 264.4
# 35                                      566.7 / 264.4
# 36                                      564.8 / 264.4
# 37                                      594.6 / 264.4
# 38                                      592.6 / 264.4
# 39                                      622.7 / 264.4
# 40                                      620.7 / 264.4
# 41                                      650.8 / 264.4
# 42                                      648.8 / 264.4
#
#    Lipid Species used as Internal Standard  Retention Time (min)  \
# 0                  SM(18:1)+H_d9_SPLASH.IS             12.737513
# 1                  SM(18:1)+H_d9_SPLASH.IS             12.662914
# 2                  SM(18:1)+H_d9_SPLASH.IS             12.580159
# 3                  SM(18:1)+H_d9_SPLASH.IS             12.572303
# 4                  SM(18:1)+H_d9_SPLASH.IS             12.486523
# 5                  SM(18:1)+H_d9_SPLASH.IS             12.472570
# 7                  SM(18:1)+H_d9_SPLASH.IS             12.411746
# 8                  SM(18:1)+H_d9_SPLASH.IS             12.349735
# 9                  SM(18:1)+H_d9_SPLASH.IS             12.373791
# 10                 SM(18:1)+H_d9_SPLASH.IS             12.059325
# 13     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              2.205949
# 17     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              2.607093
# 19     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              2.527349
# 20     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              2.639224
# 21     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              2.324839
# 25     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              2.350090
# 26     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              2.391308
# 27     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              2.779677
# 30     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              3.027516
# 32     TAG(15:0_18:1_15:0)+NH4d7_SPLASH.IS              2.929388
# 33                 SM(18:1)+H_d9_SPLASH.IS              2.649334
# 34                 SM(18:1)+H_d9_SPLASH.IS              2.637043
# 35                 SM(18:1)+H_d9_SPLASH.IS              2.586786
# 36                 SM(18:1)+H_d9_SPLASH.IS              3.174130
# 37                 SM(18:1)+H_d9_SPLASH.IS              2.507573
# 38                 SM(18:1)+H_d9_SPLASH.IS              2.517471
# 39                 SM(18:1)+H_d9_SPLASH.IS              2.572561
# 40                 SM(18:1)+H_d9_SPLASH.IS              3.041912
# 41                 SM(18:1)+H_d9_SPLASH.IS              2.557489
# 42                 SM(18:1)+H_d9_SPLASH.IS              2.726491
#
#     Peak Area of Lipid Species  Peak Area of Internal Standard  \
# 0                 4.116176e+06                    4.165659e+07
# 1                 2.433723e+07                    4.165659e+07
# 2                 1.432478e+08                    4.165659e+07
# 3                 1.268323e+08                    4.165659e+07
# 4                 5.419340e+06                    4.165659e+07
# 5                 6.447042e+06                    4.165659e+07
# 7                 4.493430e+06                    4.165659e+07
# 8                 6.606594e+06                    4.165659e+07
# 9                 2.133281e+07                    4.165659e+07
# 10                1.190904e+06                    4.165659e+07
# 13                8.077846e+04                    8.991111e+05
# 17                2.255632e+04                    8.991111e+05
# 19                3.815718e+04                    8.991111e+05
# 20                5.539265e+04                    8.991111e+05
# 21                7.467720e+04                    8.991111e+05
# 25                2.521831e+04                    8.991111e+05
# 26                1.431370e+04                    8.991111e+05
# 27                5.669030e+04                    8.991111e+05
# 30                8.465719e+03                    8.991111e+05
# 32                1.370767e+05                    8.991111e+05
# 33                5.503640e+04                    4.165659e+07
# 34                6.949528e+05                    4.165659e+07
# 35                6.102932e+06                    4.165659e+07
# 36                1.941213e+07                    4.165659e+07
# 37                1.563125e+06                    4.165659e+07
# 38                3.691389e+06                    4.165659e+07
# 39                2.610908e+06                    4.165659e+07
# 40                1.682123e+07                    4.165659e+07
# 41                2.168115e+06                    4.165659e+07
# 42                1.582402e+07                    4.165659e+07
#
#     Normalized Peak Area (Peak Area of Lipid Species / (Peak Area of Internal Standard * Tissue Weight))
# 0                                            0.000842
# 1                                            0.006390
# 2                                            0.036989
# 3                                            0.046320
# 4                                            0.001167
# 5                                            0.001996
# 7                                            0.001478
# 8                                            0.001373
# 9                                            0.005581
# 10                                           0.000103
# 13                                           0.001626
# 17                                           0.000127
# 19                                           0.000176
# 20                                           0.000234
# 21                                           0.000292
# 25                                           0.000159
# 26                                           0.000331
# 27                                           0.000286
# 30                                           0.000058
# 32                                           0.000531
# 33                                           0.000005
# 34                                           0.000139
# 35                                           0.001540
# 36                                           0.002313
# 37                                           0.000439
# 38                                           0.001349
# 39                                           0.000708
# 40                                           0.002033
# 41                                           0.000426
# 42                                           0.003043

# %%
# Change column names to camelCase
""" cn = df.columns
cn_camelCase = [x.title().replace('/','').replace(' ','').replace('(','').replace(')','') for x in cn]
cn_camelCase = [''.join([x[0].lower(), x[1:]]) for x in cn_camelCase]
cn_camelCase """
# Out:
# ['sampleNumber',
#  'sampleSubmissionDate',
#  'sampleName',
#  'sex',
#  'tissueWeightMg',
#  'treatment',
#  'tissueType',
#  'pnd',
#  'litter',
#  'individualLipidSpecies',
#  'lipidClass',
#  'mrmTransitionOfEachLipidSpecies\nParentIonFragmentIon',
#  'lipidSpeciesUsedAsInternalStandard',
#  'retentionTimeMin',
#  'peakAreaOfLipidSpecies',
#  'peakAreaOfInternalStandard',
#  'normalizedPeakAreaPeakAreaOfLipidSpeciesPeakAreaOfInternalStandard*TissueWeight']

# %%
# Save dataframe to data_path

df_clean.to_csv(os.path.join(data_path, 'clean_data.csv'), index=False)
