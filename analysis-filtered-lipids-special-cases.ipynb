# %% [markdown]
# # Imports

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import pandas as pd
import seaborn as sns
from matplotlib.legend_handler import HandlerBase
from matplotlib.text import Text
from matplotlib.legend import Legend
from scipy.stats import ranksums, ttest_ind
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.power import TTestIndPower
import statsmodels.stats.multicomp as mc

from sklearn.preprocessing import StandardScaler, MinMaxScaler

import os
import json

# %%
with open('data/paths.json','r') as f:
    paths = json.load(f)

data_path = paths["data_path"]

# %%
batch_corrected = True
nan_remove = True
scaler_term = 'minmax'
scaler = MinMaxScaler() if scaler_term=='minmax' else StandardScaler()
data_col_idx = 19 if batch_corrected else 16

test_enc_name = '_BatchCor'+str(batch_corrected)+'_NanRem'+str(nan_remove)+'_'+str(scaler_term)

print(test_enc_name)
# Out:
# _BatchCorTrue_NanRemTrue_minmax

# %% [markdown]
# ## ACTIVATE SPECIAL CASES

# %%
## UNCOMMENT WHAT IS NEEDED

## ONLY FEMALES
""" factor_to_activate = 'Sex'
factor_value = 'F'
special_folder = 'only-females/' """

## ONLY MALES
""" factor_to_activate = 'Sex'
factor_value = 'M'
special_folder = 'only-males/' """

## ONLY STRIATUM
factor_to_activate = 'Tissue Type'
factor_value = 'striatum'
special_folder = 'only-striatum/'

# %%
with open(os.path.join('results', special_folder + 'significant_lipids_pls2_treatment'+test_enc_name+'.txt'),'r') as f:
    lipid_names = f.read().splitlines()
print(lipid_names)
print(len(lipid_names))
# Out:
# ['CE(20:4)+H', 'CER(16:0)+H', 'CER(18:0)+H', 'CER(18:1)+H', 'CER(20:0)+H', 'CER(20:1)+H', 'CER(22:0)+H', 'CER(22:1)+H', 'CER(24:0)+H', 'CER(24:1)+H', 'DAG(16:0_20:3)+NH4', 'DAG(16:0_20:4)+NH4', 'DAG(16:0_22:5)+NH4', 'DAG(16:0_22:6)+NH4', 'DAG(16:1_18:1)+NH4', 'DAG(16:1_20:4)+NH4', 'DAG(18:0_22:6)+NH4', 'DAG(18:1_18:1)+NH4', 'DAG(18:1_20:3)+NH4', 'DAG(18:1_20:4)+NH4', 'DAG(18:1_22:4)+NH4', 'DAG(18:1_22:6)+NH4', 'DCER(18:0)+H', 'DCER(18:1)+H', 'DCER(20:0)+H', 'DCER(20:1)+H', 'DCER(24:1)+H', 'HCER(18:0)+H', 'HCER(18:1)+H', 'HCER(20:1)+H', 'HCER(22:1)+H', 'HCER(24:1)+H', 'LPC(16:1)+AcO', 'LPC(18:0)+AcO', 'LPC(18:1)+AcO', 'LPC(18:2)+AcO', 'LPC(18:3)+AcO', 'LPC(20:0)+AcO', 'LPC(20:1)+AcO', 'LPC(20:2)+AcO', 'LPC(20:3)+AcO', 'LPC(20:4)+AcO', 'LPC(22:4)+AcO', 'LPC(22:5)+AcO', 'LPC(22:6)+AcO', 'LPE(16:0)-H', 'LPE(18:0)-H', 'LPE(18:1)-H', 'LPE(18:2)-H', 'LPE(20:1)-H', 'LPE(20:4)-H', 'LPE(22:4)-H', 'LPE(22:5)-H', 'LPE(22:6)-H', 'LPG(16:0)-H', 'LPG(18:0)-H', 'LPI(16:0)-H', 'LPI(18:0)-H', 'LPI(18:1)-H', 'LPI(18:2)-H', 'LPI(20:1)-H', 'LPI(20:3)-H', 'LPI(20:4)-H', 'MAG(16:0)+NH4', 'MAG(16:1)+NH4', 'MAG(18:0)+NH4', 'MAG(18:1)+NH4', 'MAG(18:2)+NH4', 'MAG(20:1)+NH4', 'MAG(20:2)+NH4', 'MAG(20:3)+NH4', 'MAG(20:4)+NH4', 'MAG(22:4)+NH4', 'MAG(22:5)+NH4', 'MAG(22:6)+NH4', 'PC(14:0_18:1)+AcO', 'PC(16:0_14:0)+AcO', 'PC(16:0_16:0)+AcO', 'PC(16:0_16:1)+AcO', 'PC(16:0_18:0)+AcO', 'PC(16:0_18:1)+AcO', 'PC(16:0_18:2)+AcO', 'PC(16:0_18:3)+AcO', 'PC(16:0_20:1)+AcO', 'PC(16:0_20:2)+AcO', 'PC(16:0_20:3)+AcO', 'PC(16:0_20:4)+AcO', 'PC(16:0_20:5)+AcO', 'PC(16:0_22:4)+AcO', 'PC(16:0_22:5)+AcO', 'PC(16:1_18:2)+AcO', 'PC(18:0_14:0)+AcO', 'PC(18:0_16:1)+AcO', 'PC(18:0_18:0)+AcO', 'PC(18:0_18:1)+AcO', 'PC(18:0_18:2)+AcO', 'PC(18:0_20:3)+AcO', 'PC(18:0_20:4)+AcO', 'PC(18:1_20:1)+AcO', 'PC(18:2_16:1)+AcO', 'PC(18:2_18:2)+AcO', 'PC(18:2_20:4)+AcO', 'PE(16:0_16:0)-H', 'PE(16:0_16:1)-H', 'PE(16:0_18:1)-H', 'PE(16:0_18:2)-H', 'PE(16:0_20:1)-H', 'PE(16:0_20:2)-H', 'PE(16:0_20:3)-H', 'PE(16:0_20:4)-H', 'PE(16:0_20:5)-H', 'PE(16:0_22:4)-H', 'PE(16:0_22:5)-H', 'PE(16:0_22:6)-H', 'PE(18:0_18:1)-H', 'PE(18:0_18:2)-H', 'PE(18:0_20:1)-H', 'PE(18:0_20:3)-H', 'PE(18:0_20:4)-H', 'PE(18:0_20:5)-H', 'PE(18:0_22:4)-H', 'PE(18:0_22:5)-H', 'PE(18:0_22:6)-H', 'PE(18:1_16:1)-H', 'PE(18:1_18:1)-H', 'PE(18:1_18:2)-H', 'PE(18:1_18:3)-H', 'PE(18:1_20:1)-H', 'PE(18:1_20:3)-H', 'PE(18:1_20:4)-H', 'PE(18:1_20:5)-H', 'PE(18:1_22:4)-H', 'PE(18:1_22:5)-H', 'PE(18:1_22:6)-H', 'PE(18:2_16:1)-H', 'PE(18:2_18:2)-H', 'PE(18:2_20:1)-H', 'PE(18:2_20:4)-H', 'PE(O-16:0_16:1)-H', 'PE(O-16:0_18:1)-H', 'PE(O-16:0_18:2)-H', 'PE(O-16:0_20:3)-H', 'PE(O-16:0_20:4)-H', 'PE(O-16:0_20:5)-H', 'PE(O-16:0_22:4)-H', 'PE(O-16:0_22:6)-H', 'PE(O-18:0_16:0)-H', 'PE(O-18:0_16:1)-H', 'PE(P-16:0_16:1)-H', 'PE(P-16:0_18:1)-H', 'PE(P-16:0_18:2)-H', 'PE(P-16:0_20:1)-H', 'PE(P-16:0_20:2)-H', 'PE(P-16:0_20:3)-H', 'PE(P-16:0_20:4)-H', 'PE(P-16:0_22:4)-H', 'PE(P-16:0_22:5)-H', 'PE(P-16:0_22:6)-H', 'PE(P-16:1_18:1)-H', 'PE(P-18:0_16:0)-H', 'PE(P-18:0_16:1)-H', 'PE(P-18:0_18:1)-H', 'PE(P-18:0_18:2)-H', 'PE(P-18:0_20:1)-H', 'PE(P-18:0_20:2)-H', 'PE(P-18:0_20:3)-H', 'PE(P-18:0_20:4)-H', 'PE(P-18:0_20:5)-H', 'PE(P-18:0_22:4)-H', 'PE(P-18:0_22:5)-H', 'PE(P-18:0_22:6)-H', 'PE(P-18:1_16:0)-H', 'PE(P-18:1_16:1)-H', 'PE(P-18:1_18:0)-H', 'PE(P-18:1_18:1)-H', 'PE(P-18:1_18:2)-H', 'PE(P-18:1_20:1)-H', 'PE(P-18:1_20:2)-H', 'PE(P-18:1_20:3)-H', 'PE(P-18:1_20:4)-H', 'PE(P-18:1_20:5)-H', 'PE(P-18:1_22:4)-H', 'PE(P-18:1_22:5)-H', 'PE(P-18:1_22:6)-H', 'PE(P-18:2_20:4)-H', 'PE(P-18:2_22:6)-H', 'PG(14:0_18:1)-H', 'PG(16:0_16:0)-H', 'PG(16:0_16:1)-H', 'PG(16:0_18:0)-H', 'PG(16:0_18:1)-H', 'PG(16:0_18:2)-H', 'PG(16:0_20:1)-H', 'PG(16:0_20:2)-H', 'PG(16:0_20:3)-H', 'PG(16:0_20:4)-H', 'PG(16:0_22:4)-H', 'PG(16:0_22:6)-H', 'PG(18:0_18:1)-H', 'PG(18:0_18:2)-H', 'PG(18:0_20:3)-H', 'PG(18:0_20:4)-H', 'PG(18:0_22:4)-H', 'PG(18:0_22:6)-H', 'PG(18:1_16:1)-H', 'PG(18:1_18:1)-H', 'PG(18:1_20:4)-H', 'PG(18:1_22:4)-H', 'PG(18:1_22:6)-H', 'PG(18:2_20:4)-H', 'PI(14:0_18:1)-H ...
# 331

# %%
len(lipid_names)
# Out:
# 331

# %%
sns.set(style = 'whitegrid')

# %% [markdown]
# # Load data

# %%
data_tmp = pd.read_excel(os.path.join(data_path,'raw_data.xlsx'))
data_tmp.head()
# Out:
#    Sample Number Sample Submission Date Sample Name Sex  Tissue weight (mg)  \
# 0              1                09/2021      C20M1S   M                  56
# 1              1                09/2021      C20M1S   M                  56
# 2              1                09/2021      C20M1S   M                  56
# 3              1                09/2021      C20M1S   M                  56
# 4              1                09/2021      C20M1S   M                  56
#
#   Treatment Tissue Type  PND Litter Individual Lipid Species Lipid Class  \
# 0   control    striatum   30    C20               SM(14:0)+H          SM
# 1   control    striatum   30    C20               SM(16:0)+H          SM
# 2   control    striatum   30    C20               SM(18:0)+H          SM
# 3   control    striatum   30    C20               SM(18:1)+H          SM
# 4   control    striatum   30    C20               SM(20:0)+H          SM
#
#   MRM Transition of each lipid species\n(Parent ion / Fragment ion)  \
# 0                                      675.5 / 184.1
# 1                                      703.6 / 184.1
# 2                                      731.6 / 184.1
# 3                                      729.6 / 184.1
# 4                                      759.6 / 184.1
#
#   Lipid Species used as Internal Standard  Retention Time\n(min)  \
# 0                 SM(18:1)+H_d9_SPLASH.IS              12.737513
# 1                 SM(18:1)+H_d9_SPLASH.IS              12.662914
# 2                 SM(18:1)+H_d9_SPLASH.IS              12.580159
# 3                 SM(18:1)+H_d9_SPLASH.IS              12.572303
# 4                 SM(18:1)+H_d9_SPLASH.IS              12.486523
#
#    UNCORRECTED\nPeak Area of Lipid Species  \
# 0                             4.116176e+06
# 1                             2.433723e+07
# 2                             1.432478e+08
# 3                             1.268323e+08
# 4                             5.419340e+06
#
#    UNCORRECTED\nPeak Area of Internal Standard  \
# 0                                 6.142877e+07
# 1                                 6.142877e+07
# 2                                 6.142877e+07
# 3                                 6.142877e+07
# 4                                 6.142877e+07
#
#    UNCORRECTED\nNormalized Peak Area (Peak Area of Lipid Species / (Peak Area of Internal Standard * Tissue weight))  \
# 0                                           0.001197
# 1                                           0.007075
# 2                                           0.041642
# 3                                           0.036870
# 4                                           0.001575
#
#    BATCH CORRECTED\nPeak Area of Lipid Species  \
# 0                                 1.963161e+06
# 1                                 1.490595e+07
# 2                                 8.628739e+07
# 3                                 1.080535e+08
# 4                                 2.723486e+06
#
#    BATCH CORRECTED\nPeak Area of Internal Standard  \
# 0                                     4.165659e+07
# 1                                     4.165659e+07
# 2                                     4.165659e+07
# 3                                     4.165659e+07
# 4                                     4.165659e+07
#
#    BATCH CORRECTED\nNormalized Peak Area (Peak Area of Lipid Species / (Peak Area of Internal Standard * Tissue weight))
# 0                                           0.000842
# 1                                           0.006390
# 2                                           0.036989
# 3                                           0.046320
# 4                                           0.001167

# %%
metadata = data_tmp.iloc[:,:11]
if batch_corrected:
    data = pd.concat([metadata, data_tmp.iloc[:,19]],axis=1)
else:
    data = pd.concat([metadata, data_tmp.iloc[:,16]],axis=1)

data_stats = data.reset_index().fillna(1e-3*np.min(np.abs(data.iloc[:,-1])))
data_stats.head()
# Out:
#    index  Sample Number Sample Submission Date Sample Name Sex  \
# 0      0              1                09/2021      C20M1S   M
# 1      1              1                09/2021      C20M1S   M
# 2      2              1                09/2021      C20M1S   M
# 3      3              1                09/2021      C20M1S   M
# 4      4              1                09/2021      C20M1S   M
#
#    Tissue weight (mg) Treatment Tissue Type  PND Litter  \
# 0                  56   control    striatum   30    C20
# 1                  56   control    striatum   30    C20
# 2                  56   control    striatum   30    C20
# 3                  56   control    striatum   30    C20
# 4                  56   control    striatum   30    C20
#
#   Individual Lipid Species Lipid Class  \
# 0               SM(14:0)+H          SM
# 1               SM(16:0)+H          SM
# 2               SM(18:0)+H          SM
# 3               SM(18:1)+H          SM
# 4               SM(20:0)+H          SM
#
#    BATCH CORRECTED\nNormalized Peak Area (Peak Area of Lipid Species / (Peak Area of Internal Standard * Tissue weight))
# 0                                           0.000842
# 1                                           0.006390
# 2                                           0.036989
# 3                                           0.046320
# 4                                           0.001167

# %% [markdown]
# ## FILTERING SPECIAL CASES

# %%
data_stats = data_stats[data_stats[factor_to_activate] == factor_value].copy(deep=True)

# %%
data = data_stats.loc[data_stats['Individual Lipid Species'].isin(lipid_names)].copy(deep=True)
data.columns = ['Index','SampleNumber', 'SampleSubmissionDate', 'SampleName', 'Sex', 'TissueWeight', 'Treatment', 'TissueType', 'PND', 'Litter', 'IndividualLipidSpecies', 'LipidClass', 'PeakArea']
data.head()
# Out:
#    Index  SampleNumber SampleSubmissionDate SampleName Sex  TissueWeight  \
# 0      0             1              09/2021     C20M1S   M            56
# 1      1             1              09/2021     C20M1S   M            56
# 2      2             1              09/2021     C20M1S   M            56
# 3      3             1              09/2021     C20M1S   M            56
# 4      4             1              09/2021     C20M1S   M            56
#
#   Treatment TissueType  PND Litter IndividualLipidSpecies LipidClass  PeakArea
# 0   control   striatum   30    C20             SM(14:0)+H         SM  0.000842
# 1   control   striatum   30    C20             SM(16:0)+H         SM  0.006390
# 2   control   striatum   30    C20             SM(18:0)+H         SM  0.036989
# 3   control   striatum   30    C20             SM(18:1)+H         SM  0.046320
# 4   control   striatum   30    C20             SM(20:0)+H         SM  0.001167

# %%
data['Sex'].value_counts()
data['SampleSubmissionDate'].value_counts()
# Out:
# 09/2021    7944
# 11/2022    7944
# Name: SampleSubmissionDate, dtype: int64

# %%
data['log_area'] = np.log10(data.iloc[:,-1])
data['log_scaled_area'] = scaler.fit_transform(data[['log_area']])
data.head()
# Out:
#    Index  SampleNumber SampleSubmissionDate SampleName Sex  TissueWeight  \
# 0      0             1              09/2021     C20M1S   M            56
# 1      1             1              09/2021     C20M1S   M            56
# 2      2             1              09/2021     C20M1S   M            56
# 3      3             1              09/2021     C20M1S   M            56
# 4      4             1              09/2021     C20M1S   M            56
#
#   Treatment TissueType  PND Litter IndividualLipidSpecies LipidClass  \
# 0   control   striatum   30    C20             SM(14:0)+H         SM
# 1   control   striatum   30    C20             SM(16:0)+H         SM
# 2   control   striatum   30    C20             SM(18:0)+H         SM
# 3   control   striatum   30    C20             SM(18:1)+H         SM
# 4   control   striatum   30    C20             SM(20:0)+H         SM
#
#    PeakArea  log_area  log_scaled_area
# 0  0.000842 -3.074916         0.682074
# 1  0.006390 -2.194512         0.758062
# 2  0.036989 -1.431924         0.823882
# 3  0.046320 -1.334233         0.832314
# 4  0.001167 -2.932747         0.694344

# %% [markdown]
# # Manipulate data

# %% [markdown]
# Add a column to identify the date

# %%
def classify_date(input_date):
    if input_date == '09/2021':
        return 1
    else:
        return 2

data['dateId'] = data['SampleSubmissionDate'].apply(lambda x: classify_date(x))

# %%
## Not used..uncomment if necessary
""" df_sub = data[(data['TissueType'] == 'cortex') & (data['PND'] == 30)].copy()
df_sub['class'] = [0 if x == 'control' else 1 for x in df_sub['Treatment']]

df_pivot = df_sub.pivot_table(index='IndividualLipidSpecies', columns='SampleNumber',values='log_scaled_area',dropna=True).T


class_values = df_sub.groupby('SampleNumber').mean()['class']

print(df_pivot.columns) """
# Out:
# " df_sub = data[(data['TissueType'] == 'cortex') & (data['PND'] == 30)].copy()\ndf_sub['class'] = [0 if x == 'control' else 1 for x in df_sub['Treatment']]\n\ndf_pivot = df_sub.pivot_table(index='IndividualLipidSpecies', columns='SampleNumber',values='log_scaled_area',dropna=True).T\n\n\nclass_values = df_sub.groupby('SampleNumber').mean()['class']\n\nprint(df_pivot.columns) "

# %% [markdown]
# # Figures

# %%
data.shape
# Out:
# (15888, 16)

# %%
fig = plt.figure(figsize=(14,8), dpi=100)
ax = sns.violinplot(data=data, x='TissueType', hue='Treatment', y='log_scaled_area',split=True, inner='box')

ax.set_title('Distribution of normalized Peak Area between Striatum and Cortex', fontsize=16)
ax.set_xlabel('TissueType', fontsize=14)
ax.set_ylabel('Normalized Log Peak Area', fontsize=14)

fig.savefig(os.path.join(data_path, special_folder + "violinplot-tissue-no-date.png"), format='png', facecolor='w')

# %%
fig = plt.figure(figsize=(14,8), dpi=100)
ax = sns.violinplot(data=data, x='PND', hue='Treatment', y='log_scaled_area',split=True, inner='box')
ax.set_title('Distribution of normalized Peak Area between PND 30 and PND 60', fontsize=16)
ax.set_xlabel('PND', fontsize=16)
ax.set_ylabel('Normalized Log Peak Area', fontsize=14)
                    
fig.savefig(os.path.join(data_path, special_folder + "violinplot-pnd-no-date.png"), format='png', facecolor='w')

# %%
sns.set_style('white')

fig, ax = plt.subplots(2, 3, sharex=True, figsize=(24,16), )

opt = {'bins': 50, 'alpha': 0.2, 'palette': 'bright',
        'stat': 'probability', 'kde': True,
        'line_kws': {'lw': 2}, 'common_norm': False}

sns.histplot(data=data[data['TissueType'] == 'cortex'], x='log_scaled_area', hue='Treatment', ax=ax[0,0], legend=True, **opt)
ax[0,0].set_title('Log values, Cortex', fontsize=16)
ax[0,0].set_ylabel('Probability', fontsize=18)
ax[0,0].tick_params(axis='y', labelsize=14)
sns.histplot(data=data[data['TissueType'] == 'striatum'], x='log_scaled_area', hue='Treatment', ax=ax[1,0], legend=True, **opt)
ax[1,0].set_title('Log values, Striatum', fontsize=16)
ax[1,0].set_xlabel('Log Normalized Area', fontsize=18, color='green')
ax[1,0].set_ylabel('Probability', fontsize=18)
ax[1,0].tick_params(axis='y', labelsize=14)

sns.histplot(data=data[data['Sex'] == 'F'], x='log_scaled_area', hue='Treatment', ax=ax[0,1], legend=True, **opt)
ax[0,1].set_title('Log values, Female', fontsize=16)
ax[0,1].set_ylabel('Probability', fontsize=18)
ax[0,1].tick_params(axis='y', labelsize=14)
sns.histplot(data=data[data['Sex'] == 'M'], x='log_scaled_area', hue='Treatment', ax=ax[1,1], legend=True, **opt)
ax[1,1].set_title('Log values, Male', fontsize=16)
ax[1,1].set_xlabel('Log Normalized Area', fontsize=18, color='green')
ax[1,1].set_ylabel('Probability', fontsize=18)
ax[1,1].tick_params(axis='y', labelsize=14)

sns.histplot(data=data[data['PND'] == 30], x='log_scaled_area', hue='Treatment', ax=ax[0,2], legend=True, **opt)
ax[0,2].set_title('Log values, PND 30', fontsize=16)
ax[0,2].set_ylabel('Probability', fontsize=18)
ax[0,2].tick_params(axis='y', labelsize=14)
sns.histplot(data=data[data['PND'] == 60], x='log_scaled_area', hue='Treatment', ax=ax[1,2], legend=True, **opt)
ax[1,2].set_title('Log values, PND 60', fontsize=16)
ax[1,2].set_xlabel('Log Normalized Area', fontsize=18, color='green')
ax[1,2].set_ylabel('Probability', fontsize=18)
ax[1,2].tick_params(axis='y', labelsize=14)

fig.savefig(os.path.join(data_path, special_folder + "distribution-3cases-no-date.png"), format='png', facecolor='w', dpi=300)

plt.show()

# %%
sns.set_style('white')

fig, ax = plt.subplots(2, 2, sharex=True, figsize=(24,14))

opt = {'bins': 50, 'alpha': 0.2, 'palette': 'bright',
        'stat': 'probability', 'kde': True,
        'line_kws': {'lw': 2}, 'common_norm': False}

sns.histplot(data=data[(data['TissueType'] == 'striatum') & (data['PND'] == 30)], x='log_scaled_area', hue='Treatment', ax=ax[0,0], legend=False, **opt)
ax[0,0].set_title('Log values, Striatum PND-30')
sns.histplot(data=data[(data['TissueType'] == 'striatum') & (data['PND'] == 60)], x='log_scaled_area', hue='Treatment', ax=ax[1,0], legend=False, **opt)
ax[1,0].set_title('Log values, Striatum PND-60')

sns.histplot(data=data[(data['TissueType'] == 'striatum') & (data['Sex'] == 'F')], x='log_scaled_area', hue='Treatment', ax=ax[0,1], legend=False, **opt)
ax[0,1].set_title('Log values, Striatum Female')
sns.histplot(data=data[(data['TissueType'] == 'striatum') & (data['Sex'] == 'M')], x='log_scaled_area', hue='Treatment', ax=ax[1,1], legend=False, **opt)
ax[1,1].set_title('Log values, Striatum Male')

fig.savefig(os.path.join(data_path,"distribution-Striatum-2cases.svg"), format='svg', facecolor='w')

plt.show()

# %% [markdown]
# # Statistics

# %% [markdown]
# ## Wilcoxon test applied on the data with no normalization

# %% [markdown]
# #### Data divided by tissue

# %%
tissue = ['striatum','cortex']
sex = ['F', 'M']
pnd = [30,60]
var_name = 'log_scaled_area'


for t in tissue:
    a = data[(data['Treatment'] == 'control') & (data['TissueType']==t)][var_name]
    b = data[(data['Treatment'] == 'deltamethrin') & (data['TissueType']==t)][var_name]

    a = a.dropna()
    b = b.dropna()

    print(f'Tissue: {t}. P-value: {ranksums(a,b).pvalue:.2e}')
# Out:
# Tissue: striatum. P-value: 5.14e-01
# Tissue: cortex. P-value: 7.97e-01

# %% [markdown]
# #### Data divided by gender

# %%
for g in sex:
    a = data[(data['Treatment'] == 'control') & (data['Sex']==g)][var_name]
    b = data[(data['Treatment'] == 'deltamethrin') & (data['Sex']==g)][var_name]

    a = a.dropna()
    b = b.dropna()

    print(f'Gender: {g}. P-value: {ranksums(a,b).pvalue:.2e}')
# Out:
# Gender: F. P-value: 1.65e-01
# Gender: M. P-value: 6.89e-01

# %% [markdown]
# #### Data divided by PND

# %%
for p in pnd:
    a = data[(data['Treatment'] == 'control') & (data['PND']==p)][var_name]
    b = data[(data['Treatment'] == 'deltamethrin') & (data['PND']==p)][var_name]

    a = a.dropna()
    b = b.dropna()

    print(f'PND: {p}. P-value: {ranksums(a,b).pvalue:.2e}')
# Out:
# PND: 30. P-value: 9.50e-01
# PND: 60. P-value: 3.19e-01

# %% [markdown]
# ## T-test applied on the data with log normalization

# %% [markdown]
# #### Data divided by tissue

# %%
tissue = ['striatum','cortex']
sex = ['F', 'M']
pnd = [30,60]
var_name = 'log_scaled_area'

if (factor_to_activate != 'Tissue Type'):
    with open(os.path.join('data', special_folder + 'ttest-no-date'+test_enc_name+'.txt'), 'a') as f:
        f.write('T-test: Considering Tissue Type'+'\n')
        for t in tissue:
            a = data[(data['Treatment'] == 'control') & (data['TissueType']==t)][var_name]
            b = data[(data['Treatment'] == 'deltamethrin') & (data['TissueType']==t)][var_name]

            a = a.dropna()
            b = b.dropna()

            print(f'Tissue: {t}. P-value: {ttest_ind(a,b).pvalue:.2e}')
            f.write(f'Tissue: {t}. P-value: {ttest_ind(a,b).pvalue:.2e}\n')
        f.write(f'\n\n\n')

# %% [markdown]
# #### Data divided by gender

# %%
if (factor_to_activate != 'Sex'):
    with open(os.path.join('data', special_folder + 'ttest-no-date'+test_enc_name+'.txt'), 'a') as f:
        f.write('T-test: Considering Gender Type'+'\n')
        for g in sex:
            a = data[(data['Treatment'] == 'control') & (data['Sex']==g)][var_name]
            b = data[(data['Treatment'] == 'deltamethrin') & (data['Sex']==g)][var_name]

            a = a.dropna()
            b = b.dropna()

            f.write(f'Gender: {g}. P-value: {ttest_ind(a,b).pvalue:.2e}\n')
            print(f'Gender: {g}. P-value: {ttest_ind(a,b).pvalue:.2e}')
        f.write(f'\n\n\n')
# Out:
# Gender: F. P-value: 3.25e-02
# Gender: M. P-value: 9.98e-01

# %% [markdown]
# #### Data divided by PND

# %%
if (factor_to_activate != 'PND'):
    with open(os.path.join('data', special_folder + 'ttest-no-date'+test_enc_name+'.txt'), 'a') as f:
        f.write('T-test: Considering PND'+'\n')
        for p in pnd:
            a = data[(data['Treatment'] == 'control') & (data['PND']==p)][var_name]
            b = data[(data['Treatment'] == 'deltamethrin') & (data['PND']==p)][var_name]

            a = a.dropna()
            b = b.dropna()

            f.write(f'PND: {p}. P-value: {ttest_ind(a,b).pvalue:.2e}\n')
            print(f'PND: {p}. P-value: {ranksums(a,b).pvalue:.2e}')
        f.write(f'\n\n\n')
# Out:
# PND: 30. P-value: 1.40e-04
# PND: 60. P-value: 4.28e-01

# %% [markdown]
# ## Three-way ANOVA on log normalized data
#
# #### Quelli singoli sono mediati su tutto il resto. Mentre l'effetto del secondo oridne dice che è vero che partono da livelli differenti diversi striato e corteccia, ma l'effetto del trattamento ha effetto anche se loro sono già diversi

# %%
if (factor_to_activate == 'Sex'):
    model = ols('log_scaled_area ~ C(Treatment) + C(TissueType) + C(dateId) + C(PND) + C(PND):C(Treatment) + C(Treatment) + C(TissueType):C(Treatment) + C(dateId):C(Treatment)', data=data).fit()
elif (factor_to_activate == 'Tissue Type'):
    model = ols('log_scaled_area ~ C(Sex) + C(Treatment) + C(dateId) + C(PND) + C(Sex):C(Treatment) + C(PND):C(Treatment) + C(Treatment) + C(dateId):C(Treatment)', data=data).fit()
elif (factor_to_activate == 'PND'):
    model = ols('log_scaled_area ~ C(Sex) + C(Treatment) + C(dateId) + C(TissueType) + C(Sex):C(Treatment) + C(Treatment) + C(TissueType):C(Treatment) + C(dateId):C(Treatment)', data=data).fit()

tb = sm.stats.anova_lm(model, typ=2)

with open(os.path.join('data', special_folder + 'ttest-no-date'+test_enc_name+'.txt'), 'a') as f:
    f.write('ANOVA'+'\n')
    f.write(f'{tb}\n\n\n')

print(tb)
# Out:
#                             sum_sq       df          F    PR(>F)
# C(Sex)                    0.216354      1.0  18.488405  0.000017
# Treatment                 0.009954      1.0   0.850591  0.356399
# C(dateId)                 0.154881      1.0  13.235246  0.000276
# C(PND)                    0.103463      1.0   8.841408  0.002949
# C(Treatment)              0.026827      1.0   2.292477  0.130022
# C(Sex):C(Treatment)       0.026711      1.0   2.282574  0.130855
# C(PND):C(Treatment)       0.001700      1.0   0.145252  0.703120
# C(dateId):C(Treatment)    0.028532      1.0   2.438221  0.118430
# Residual                185.829902  15880.0        NaN       NaN

# %%
model = ols('log_scaled_area ~ C(Sex) + C(PND) + C(Treatment) + C(TissueType) + C(PND):C(Treatment) + C(Sex):C(Treatment) + C(TissueType):C(Treatment)', data=data).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                                sum_sq      df         F    PR(>F)
# C(Sex)                       0.035268     1.0  2.214418  0.136787
# C(PND)                       0.019815     1.0  1.244123  0.264729
# C(Treatment)                 0.005728     1.0  0.359627  0.548739
# C(TissueType)                0.000459     1.0  0.028833  0.865172
# C(PND):C(Treatment)          0.027778     1.0  1.744157  0.186671
# C(Sex):C(Treatment)          0.024025     1.0  1.508477  0.219427
# C(TissueType):C(Treatment)   0.000051     1.0  0.003217  0.954773
# Residual                    83.582709  5248.0       NaN       NaN

# %% [markdown]
# ### Anova only striatum

# %%
data_striatum = data[data['TissueType'] == 'striatum'].copy(deep=True)

# %%
model = ols('log_scaled_area ~ C(Sex) + C(Treatment)  + C(Sex):C(Treatment)', data=data_striatum).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                         sum_sq      df         F    PR(>F)
# C(Sex)                0.007910     1.0  0.716655  0.397312
# C(Treatment)          0.000150     1.0  0.013588  0.907209
# C(Sex):C(Treatment)   0.001171     1.0  0.106090  0.744663
# Residual             32.801092  2972.0       NaN       NaN

# %%
model = ols('log_scaled_area ~ C(Sex) + C(PND) + C(Treatment)+ C(PND):C(Treatment) + C(Sex):C(Treatment)', data=data_striatum).fit()
sm.stats.anova_lm(model, typ=2)
# Out:
#                         sum_sq      df         F    PR(>F)
# C(Sex)                0.007910     1.0  0.716792  0.397266
# C(PND)                0.028204     1.0  2.555981  0.109984
# C(Treatment)          0.000150     1.0  0.013591  0.907201
# C(PND):C(Treatment)   0.000149     1.0  0.013495  0.907529
# C(Sex):C(Treatment)   0.001171     1.0  0.106111  0.744639
# Residual             32.772739  2970.0       NaN       NaN

# %% [markdown]
# # Single lipids statistics

# %% [markdown]
# ## Define lipids list

# %%
lipids_list = data['IndividualLipidSpecies'].unique()
print(lipids_list.shape[0])
# Out:
# 331

# %% [markdown]
# ## Test lipid

# %%
data_lipid = data[data['IndividualLipidSpecies'] == lipids_list[0]]

from scipy.stats import ttest_ind
multcomp = mc.MultiComparison(data_lipid['log_scaled_area'], groups=data_lipid['Treatment'])
res = multcomp.allpairtest(ttest_ind)[1][2][0]
print(res)
res = multcomp.allpairtest(ttest_ind)[0]
print(res)
# Out:
# 0.2280255712482985
# Test Multiple Comparison ttest_ind
# FWER=0.05 method=bonf
# alphacSidak=0.05, alphacBonf=0.050
# ==================================================
#  group1    group2     stat   pval pval_corr reject
# --------------------------------------------------
# control deltamethrin 1.2218 0.228     0.228  False
# --------------------------------------------------

# %% [markdown]
# ## Analysis control vs treatment

# %%
lipids_list.shape
# Out:
# (331,)

# %%
import itertools
factor = 'Treatment'
results_all = []
for l in lipids_list:
    data_lipid = data[data['IndividualLipidSpecies'] == l]
    if data_lipid[factor].unique().size > 1: # Some lipids are not found in both classes
        for c in itertools.combinations(data_lipid[factor].unique(),2):
            a = data_lipid[data_lipid[factor] == c[0]]['log_scaled_area'].values
            b = data_lipid[data_lipid[factor] == c[1]]['log_scaled_area'].values
            pvalue = ttest_ind(a,b)[1]
            fc = np.mean(a)/np.mean(b)
            cd = np.abs((np.mean(a) - np.mean(b)))
            cd /= np.sqrt(
                ((a.size - 1)*np.var(a) + (b.size - 1)*np.var(b)) / (a.size + b.size - 2)
            )
            n_samples = a.size
            sp = TTestIndPower().power(effect_size=cd, nobs1=n_samples, alpha=0.05)
            results_all.append([l, fc, pvalue, c[0], c[1], cd, n_samples, sp])

colnames = ['lipid', 'fc', 'p', factor+'1', factor+'2', 'effectSize', 'sampleSize', 'statisticalPower']
results_all = pd.DataFrame(data=results_all, columns= colnames)
results_all.head()
# Out:
#         lipid        fc         p Treatment1    Treatment2  effectSize  \
# 0  SM(14:0)+H  1.006213  0.228026    control  deltamethrin    0.360275
# 1  SM(16:0)+H  1.005196  0.150465    control  deltamethrin    0.431201
# 2  SM(18:0)+H  1.007617  0.107636    control  deltamethrin    0.483880
# 3  SM(18:1)+H  1.003778  0.177846    control  deltamethrin    0.403507
# 4  SM(20:0)+H  1.011843  0.280226    control  deltamethrin    0.322213
#
#    sampleSize  statisticalPower
# 0          24          0.231018
# 1          24          0.309773
# 2          24          0.375122
# 3          24          0.277600
# 4          24          0.194106

# %% [markdown]
# ### Statistical power with average effectSize

# %%
es_mean = np.median(results_all['effectSize'][results_all['p']<0.05])
# es_mean = 0.8
print(es_mean)
n_mice = 24
statisticalPower = TTestIndPower().power(effect_size=es_mean, nobs1=n_mice, alpha=0.05)
print(statisticalPower)
# Out:
# 0.5119102514320559
# 0.4116104853507485

# %% [markdown]
# ### Given an effect size, and a statistical power, determine n_mice

# %%
es_mean = 0.7
alpha = 0.05
statisticalPower = 0.8
n_mice_ideal = TTestIndPower().solve_power(effect_size=es_mean, alpha=alpha, power=statisticalPower)
print(n_mice_ideal)
# Out:
# 33.02456951586259

# %% [markdown]
# ## Plots

# %%
def adjustlabels(fig, labels, max_iter=1000, eps=0.01, delta=0.1, 
                 clip_to_axes=True, pad=0.1):
    N = len(labels)
    widths = np.zeros(N)
    heights = np.zeros(N)
    centers = np.zeros((N, 2))
    for i,l in enumerate(labels):
        bb = l.get_window_extent(renderer=fig.canvas.get_renderer())
        bb = bb.transformed(plt.gca().transData.inverted())
        widths[i] = bb.width
        heights[i] = bb.height
        centers[i] = (bb.min + bb.max)/2
        
    ylim = plt.gca().get_ylim()
    xlim = plt.gca().get_xlim()    

    def clip():
        for i in range(N):
            centers[i,0] = max(centers[i,0], xlim[0] + widths[i]/2 + pad)
            centers[i,0] = min(centers[i,0], xlim[1] - widths[i]/2 - pad)
            centers[i,1] = max(centers[i,1], ylim[0] + heights[i]/2 + pad)
            centers[i,1] = min(centers[i,1], ylim[1] - heights[i]/2 - pad)
            labels[i].set_position(centers[i])
    clip()

    for i in range(max_iter):
        stop = True
        for a in range(N):
            for b in range(N):
                if ((a!=b) and
                    (np.abs(centers[a,0]-centers[b,0]) < (widths[a]+widths[b])/2 + delta) and
                    (np.abs(centers[a,1]-centers[b,1]) < (heights[a]+heights[b])/2 +  delta)):
                    
                    d = centers[a] - centers[b]
                    centers[a] += d * eps
                    centers[b] -= d * eps
                    labels[a].set_position(centers[a])
                    labels[b].set_position(centers[b])
                    if clip_to_axes:
                        clip()
                    stop = False
        if stop:
            break

# %%
results_all.shape
# Out:
# (41, 8)

# %%
def plot_volcano(results_all, fc_threshold=0.3, pvalue_threshold=1.5, filename="test.png"):

    class TextHandlerB(HandlerBase):
        def create_artists(self, legend, text ,xdescent, ydescent,
                            width, height, fontsize, trans):
            tx = Text(width/2.,height/2, text, fontsize=fontsize,
                    ha="center", va="center", fontweight="bold")
            return [tx]

    Legend.update_default_handler_map({str : TextHandlerB()})       
    
    #col = np.where(np.log2(results_all['fc']) < -fc_threshold,'r',np.where(np.log2(results_all['fc']) > fc_threshold,'g','k'))
    col = np.where(-np.log10(results_all['p']) < pvalue_threshold, 'k', 
                            np.where(np.log2(results_all['fc']) < -fc_threshold,'r',np.where(np.log2(results_all['fc']) > fc_threshold,'g','k')))

    fig = plt.figure(figsize=(14,12))
    plt.scatter(np.log2(results_all['fc']), -np.log10(results_all['p']), c=col)
    y_max_value = plt.gca().get_ylim()[1]
    shownlabels = []
    l_ha = ['right','left']
    elem_counter = 1
    legend_data_handles = []
    legend_data_labels = []
    for i in range(results_all.shape[0]): 

        x = np.log2(results_all.iloc[i]['fc'])
        y = -np.log10(results_all.iloc[i]['p'])
        aa = np.random.rand()*3 - 1.5 + 0.5 * np.sign(x)
        ii = np.sign(aa) * 0.5 + 0.5
        if (np.abs(x) > fc_threshold) and (y > pvalue_threshold):
            l = plt.text(x, y + 0.03*y_max_value, elem_counter, va='center', color='k', fontsize=14, zorder=10,bbox=dict(facecolor='w', edgecolor='#777777', boxstyle='round', linewidth=.5, pad=.1))
            """ l = plt.text(x+0.01*aa, y,
                         results_all.iloc[i]['lipid'],ha=l_ha[int(ii)], va='center', color='k', 
                         fontsize=10, zorder=10,bbox=dict(facecolor='w', edgecolor='#777777', boxstyle='round', linewidth=.5, pad=.2)) """
            #shownlabels.append(l)
            legend_circle = Line2D([0], [0], marker='o', color='w', markerfacecolor='r' if x < -fc_threshold else 'g', markersize=10)
            legend_data_handles.append(legend_circle)
            legend_data_labels.append(str(elem_counter) + '-' + results_all.iloc[i]['lipid'])
            #legend_data_keeper.update({str(elem_counter): results_all.iloc[i]['lipid']})
            elem_counter += 1
    #adjustlabels(fig, shownlabels)
    plt.legend(handles=legend_data_handles,labels=legend_data_labels, loc='upper left', bbox_to_anchor=(1, 0.5), title='Legend')
    plt.xlabel('log FC',)
    plt.ylabel('-log10 (Pvalue)')
    plt.rc('axes', labelsize=18) 
    fig.savefig(os.path.join(data_path,filename), format='png', facecolor='w', dpi=300)

    plt.show()

# %%
plot_volcano(results_all,fc_threshold=0.1, pvalue_threshold=1, filename= special_folder + "volcano-plot-treatment-fc_01_pv_1-no-date.png")

# %% [markdown]
# ## Analysis striatum vs cortex

# %%
factor = 'TissueType'
results_all = []
for l in lipids_list:
    data_lipid = data[data['IndividualLipidSpecies'] == l]
    if data_lipid[factor].unique().size > 1: # Some lipids are not found in both classes
        for c in itertools.combinations(data_lipid[factor].unique(),2):
            a = data_lipid[data_lipid[factor] == c[0]]['log_scaled_area'].values
            b = data_lipid[data_lipid[factor] == c[1]]['log_scaled_area'].values
            pvalue = ttest_ind(a,b)[1]
            fc = np.mean(a)/np.mean(b)
            results_all.append([l, fc, pvalue, c[0], c[1]])

colnames = ['lipid', 'fc', 'p', factor+'1', factor+'2']
results_all = pd.DataFrame(data=results_all, columns= colnames)
results_all.head()

results_all.to_csv(os.path.join('results','tissue_treatment.csv'))

# %%
plot_volcano(results_all,fc_threshold=0.1, pvalue_threshold=1, filename= special_folder + "volcano-plot-tissuetype-fc_01_pv_1-no-date.png")

# %% [markdown]
# ## Analysis 30 vs 60

# %%
factor = 'PND'
results_all = []
for l in lipids_list:
    data_lipid = data[data['IndividualLipidSpecies'] == l]
    if data_lipid[factor].unique().size > 1: # Some lipids are not found in both classes
        for c in itertools.combinations(data_lipid[factor].unique(),2):
            a = data_lipid[data_lipid[factor] == c[0]]['log_scaled_area'].values
            b = data_lipid[data_lipid[factor] == c[1]]['log_scaled_area'].values
            pvalue = ttest_ind(a,b)[1]
            fc = np.mean(a)/np.mean(b)
            results_all.append([l, fc, pvalue, c[0], c[1]])

colnames = ['lipid', 'fc', 'p', factor+'1', factor+'2']
results_all = pd.DataFrame(data=results_all, columns= colnames)
results_all.head()

results_all.to_csv(os.path.join('results','pnd_treatment.csv'))

# %%
plot_volcano(results_all,fc_threshold=0.1, pvalue_threshold=1, filename= special_folder + "volcano-plot-PND-fc_01_pv_1-no-date.png")

# %% [markdown]
# ## Analysis male vs female

# %%
factor = 'Sex'
results_all = []
for l in lipids_list:
    data_lipid = data[data['IndividualLipidSpecies'] == l]
    if data_lipid[factor].unique().size > 1: # Some lipids are not found in both classes
        for c in itertools.combinations(data_lipid[factor].unique(),2):
            a = data_lipid[data_lipid[factor] == c[0]]['log_scaled_area'].values
            b = data_lipid[data_lipid[factor] == c[1]]['log_scaled_area'].values
            pvalue = ttest_ind(a,b)[1]
            fc = np.mean(a)/np.mean(b)
            results_all.append([l, fc, pvalue, c[0], c[1]])

colnames = ['lipid', 'fc', 'p', factor+'1', factor+'2']
results_all = pd.DataFrame(data=results_all, columns= colnames)
results_all.head()

results_all.to_csv(os.path.join('results','sex_treatment.csv'))

# %%
plot_volcano(results_all,fc_threshold=0.1, pvalue_threshold=1, filename= special_folder + "volcano-plot-gender-fc_01_pv_1-no-date.png")
